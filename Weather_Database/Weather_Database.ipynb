# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests
import time
from datetime import datetime

# %%
# Create a set of 2000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Pack the latitudes and longitudes as pairs by zipping them with the zip function.
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination using the citipy module.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information to the city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pacifica
# Processing Record 2 of Set 1 | opuwo
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | ayan
# Processing Record 5 of Set 1 | san patricio
# Processing Record 6 of Set 1 | san quintin
# Processing Record 7 of Set 1 | husavik
# Processing Record 8 of Set 1 | sola
# Processing Record 9 of Set 1 | nome
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | aklavik
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | bangangte
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | tarauaca
# Processing Record 16 of Set 1 | bathsheba
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | norman wells
# Processing Record 19 of Set 1 | paysandu
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | okhotsk
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | soller
# Processing Record 27 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 1 | gat
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | kruisfontein
# Processing Record 31 of Set 1 | kloulklubed
# Processing Record 32 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 1 | deputatskiy
# Processing Record 34 of Set 1 | zachagansk
# City not found. Skipping...
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | berezna
# Processing Record 37 of Set 1 | morondava
# Processing Record 38 of Set 1 | la romana
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | brandon
# Processing Record 42 of Set 1 | lisbon
# Processing Record 43 of Set 1 | bengkulu
# Processing Record 44 of Set 1 | rawson
# Processing Record 45 of Set 1 | chukhloma
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | balingasay
# Processing Record 48 of Set 1 | sandwick
# Processing Record 49 of Set 1 | rawah
# Processing Record 50 of Set 1 | mount gambier
# Processing Record 1 of Set 2 | zambrano
# Processing Record 2 of Set 2 | mazamitla
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | los llanos de aridane
# Processing Record 6 of Set 2 | geraldton
# Processing Record 7 of Set 2 | minab
# Processing Record 8 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 2 | santa rosa
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | sangar
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | uruzgan
# Processing Record 14 of Set 2 | goure
# Processing Record 15 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 2 | portland
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | saint anthony
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | as
# City not found. Skipping...
# Processing Record 23 of Set 2 | nikolskoye
# Processing Record 24 of Set 2 | nikel
# Processing Record 25 of Set 2 | porto novo
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | dalvik
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | pacific grove
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | ranong
# Processing Record 32 of Set 2 | marienburg
# Processing Record 33 of Set 2 | pevek
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | kavieng
# Processing Record 36 of Set 2 | talnakh
# Processing Record 37 of Set 2 | bambous virieux
# Processing Record 38 of Set 2 | tecoanapa
# Processing Record 39 of Set 2 | qaanaaq
# Processing Record 40 of Set 2 | bandarbeyla
# Processing Record 41 of Set 2 | lahij
# Processing Record 42 of Set 2 | yelan
# Processing Record 43 of Set 2 | dhidhdhoo
# Processing Record 44 of Set 2 | gamba
# Processing Record 45 of Set 2 | port hardy
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | hualmay
# Processing Record 48 of Set 2 | dwarka
# Processing Record 49 of Set 2 | saint michael
# Processing Record 50 of Set 2 | thompson
# Processing Record 1 of Set 3 | dunedin
# Processing Record 2 of Set 3 | mataura
# Processing Record 3 of Set 3 | marzuq
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | iqaluit
# Processing Record 6 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | abalak
# Processing Record 9 of Set 3 | qandala
# Processing Record 10 of Set 3 | cockburn town
# Processing Record 11 of Set 3 | manaure
# Processing Record 12 of Set 3 | moron
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | charagua
# Processing Record 15 of Set 3 | mao
# Processing Record 16 of Set 3 | vila velha
# Processing Record 17 of Set 3 | saint-georges
# Processing Record 18 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 3 | lompoc
# Processing Record 20 of Set 3 | kalabo
# Processing Record 21 of Set 3 | airai
# Processing Record 22 of Set 3 | alpena
# Processing Record 23 of Set 3 | zhigansk
# Processing Record 24 of Set 3 | tuktoyaktuk
# Processing Record 25 of Set 3 | beterou
# Processing Record 26 of Set 3 | meulaboh
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | alice springs
# Processing Record 29 of Set 3 | butaritari
# Processing Record 30 of Set 3 | jacmel
# Processing Record 31 of Set 3 | pisco
# Processing Record 32 of Set 3 | punta arenas
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | havelock
# Processing Record 35 of Set 3 | codrington
# Processing Record 36 of Set 3 | itoman
# Processing Record 37 of Set 3 | lagoa
# Processing Record 38 of Set 3 | taganak
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | saint george
# Processing Record 41 of Set 3 | nyurba
# Processing Record 42 of Set 3 | navolato
# Processing Record 43 of Set 3 | mayo
# Processing Record 44 of Set 3 | balakhninskiy
# Processing Record 45 of Set 3 | tianmen
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | vardo
# Processing Record 48 of Set 3 | lorengau
# Processing Record 49 of Set 3 | dudinka
# Processing Record 50 of Set 3 | turayf
# Processing Record 1 of Set 4 | bardiyah
# Processing Record 2 of Set 4 | alofi
# Processing Record 3 of Set 4 | flinders
# Processing Record 4 of Set 4 | roverud
# Processing Record 5 of Set 4 | verkhovye
# Processing Record 6 of Set 4 | aqtobe
# Processing Record 7 of Set 4 | kapit
# Processing Record 8 of Set 4 | narsaq
# Processing Record 9 of Set 4 | pakpattan
# Processing Record 10 of Set 4 | umba
# Processing Record 11 of Set 4 | kudahuvadhoo
# Processing Record 12 of Set 4 | avarua
# Processing Record 13 of Set 4 | mugla
# Processing Record 14 of Set 4 | severo-kurilsk
# Processing Record 15 of Set 4 | nadym
# Processing Record 16 of Set 4 | kununurra
# Processing Record 17 of Set 4 | pangnirtung
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | shingu
# Processing Record 20 of Set 4 | xining
# Processing Record 21 of Set 4 | hay river
# Processing Record 22 of Set 4 | sarkand
# Processing Record 23 of Set 4 | hermanus
# Processing Record 24 of Set 4 | nouakchott
# Processing Record 25 of Set 4 | foso
# Processing Record 26 of Set 4 | ribeira grande
# Processing Record 27 of Set 4 | palaikastron
# Processing Record 28 of Set 4 | timizart
# Processing Record 29 of Set 4 | asau
# Processing Record 30 of Set 4 | mount isa
# Processing Record 31 of Set 4 | baryatino
# Processing Record 32 of Set 4 | saint-joseph
# Processing Record 33 of Set 4 | espinosa
# Processing Record 34 of Set 4 | tura
# Processing Record 35 of Set 4 | micasasa
# Processing Record 36 of Set 4 | mendeleyevo
# Processing Record 37 of Set 4 | cidreira
# Processing Record 38 of Set 4 | waddan
# Processing Record 39 of Set 4 | burns lake
# Processing Record 40 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 4 | puerto parra
# Processing Record 42 of Set 4 | port macquarie
# Processing Record 43 of Set 4 | tiarei
# Processing Record 44 of Set 4 | waingapu
# Processing Record 45 of Set 4 | east london
# Processing Record 46 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 4 | guerrero negro
# Processing Record 48 of Set 4 | katsuura
# Processing Record 49 of Set 4 | karhal
# Processing Record 50 of Set 4 | comodoro rivadavia
# Processing Record 1 of Set 5 | stephenville
# Processing Record 2 of Set 5 | haines junction
# Processing Record 3 of Set 5 | berlevag
# Processing Record 4 of Set 5 | sipe sipe
# Processing Record 5 of Set 5 | rudnogorsk
# Processing Record 6 of Set 5 | cabo san lucas
# Processing Record 7 of Set 5 | yerofey pavlovich
# Processing Record 8 of Set 5 | karaman
# Processing Record 9 of Set 5 | conceicao do araguaia
# Processing Record 10 of Set 5 | upernavik
# Processing Record 11 of Set 5 | warmbad
# Processing Record 12 of Set 5 | kaitangata
# Processing Record 13 of Set 5 | esperance
# Processing Record 14 of Set 5 | port alfred
# Processing Record 15 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 5 | tucuman
# Processing Record 17 of Set 5 | yadgir
# Processing Record 18 of Set 5 | makakilo city
# Processing Record 19 of Set 5 | birsk
# Processing Record 20 of Set 5 | shitanjing
# Processing Record 21 of Set 5 | marsh harbour
# Processing Record 22 of Set 5 | hami
# Processing Record 23 of Set 5 | yara
# Processing Record 24 of Set 5 | cap-chat
# Processing Record 25 of Set 5 | huarmey
# Processing Record 26 of Set 5 | katobu
# Processing Record 27 of Set 5 | kenai
# Processing Record 28 of Set 5 | naze
# Processing Record 29 of Set 5 | morant bay
# Processing Record 30 of Set 5 | hithadhoo
# Processing Record 31 of Set 5 | mackay
# Processing Record 32 of Set 5 | salinopolis
# Processing Record 33 of Set 5 | port lincoln
# Processing Record 34 of Set 5 | lemesos
# City not found. Skipping...
# Processing Record 35 of Set 5 | rocha
# Processing Record 36 of Set 5 | chicama
# Processing Record 37 of Set 5 | chekhov
# Processing Record 38 of Set 5 | narasannapeta
# Processing Record 39 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 5 | victoria
# Processing Record 41 of Set 5 | poum
# Processing Record 42 of Set 5 | indramayu
# Processing Record 43 of Set 5 | seoul
# Processing Record 44 of Set 5 | dingle
# Processing Record 45 of Set 5 | fort nelson
# Processing Record 46 of Set 5 | nizwa
# Processing Record 47 of Set 5 | mayahi
# Processing Record 48 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 5 | komsomolskiy
# Processing Record 50 of Set 5 | tobermory
# Processing Record 1 of Set 6 | vao
# Processing Record 2 of Set 6 | bandar-e anzali
# Processing Record 3 of Set 6 | cape town
# Processing Record 4 of Set 6 | kahului
# Processing Record 5 of Set 6 | kleive
# Processing Record 6 of Set 6 | georgetown
# Processing Record 7 of Set 6 | angoche
# Processing Record 8 of Set 6 | luis correia
# Processing Record 9 of Set 6 | port elizabeth
# Processing Record 10 of Set 6 | trencin
# Processing Record 11 of Set 6 | adre
# Processing Record 12 of Set 6 | kaeo
# Processing Record 13 of Set 6 | egvekinot
# Processing Record 14 of Set 6 | amli
# Processing Record 15 of Set 6 | pangkalanbuun
# Processing Record 16 of Set 6 | te anau
# Processing Record 17 of Set 6 | atar
# Processing Record 18 of Set 6 | borovoy
# Processing Record 19 of Set 6 | tessalit
# Processing Record 20 of Set 6 | buala
# Processing Record 21 of Set 6 | otavi
# Processing Record 22 of Set 6 | kimbe
# Processing Record 23 of Set 6 | visnes
# Processing Record 24 of Set 6 | salalah
# Processing Record 25 of Set 6 | vila franca do campo
# Processing Record 26 of Set 6 | yanai
# Processing Record 27 of Set 6 | roald
# Processing Record 28 of Set 6 | provideniya
# Processing Record 29 of Set 6 | byron bay
# Processing Record 30 of Set 6 | simao
# Processing Record 31 of Set 6 | celestun
# Processing Record 32 of Set 6 | richards bay
# Processing Record 33 of Set 6 | khani
# Processing Record 34 of Set 6 | san juan bautista
# Processing Record 35 of Set 6 | tandahimba
# Processing Record 36 of Set 6 | the valley
# Processing Record 37 of Set 6 | faya
# Processing Record 38 of Set 6 | pouembout
# Processing Record 39 of Set 6 | alekseyevsk
# Processing Record 40 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 6 | dakar
# Processing Record 42 of Set 6 | sambava
# Processing Record 43 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 6 | banjar
# Processing Record 45 of Set 6 | bagdarin
# Processing Record 46 of Set 6 | talcahuano
# Processing Record 47 of Set 6 | sobolevo
# Processing Record 48 of Set 6 | saint-augustin
# Processing Record 49 of Set 6 | kropotkin
# Processing Record 50 of Set 6 | phalodi
# Processing Record 1 of Set 7 | hambantota
# Processing Record 2 of Set 7 | hirado
# Processing Record 3 of Set 7 | ponta do sol
# Processing Record 4 of Set 7 | visby
# Processing Record 5 of Set 7 | tiksi
# Processing Record 6 of Set 7 | nizhniy tsasuchey
# Processing Record 7 of Set 7 | nizhniy ufaley
# Processing Record 8 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 7 | mandalgovi
# Processing Record 10 of Set 7 | sao miguel do araguaia
# Processing Record 11 of Set 7 | micheweni
# Processing Record 12 of Set 7 | aykhal
# Processing Record 13 of Set 7 | mpika
# Processing Record 14 of Set 7 | kidal
# Processing Record 15 of Set 7 | quatre cocos
# Processing Record 16 of Set 7 | anzio
# Processing Record 17 of Set 7 | namibe
# Processing Record 18 of Set 7 | plettenberg bay
# Processing Record 19 of Set 7 | freeport
# Processing Record 20 of Set 7 | korla
# Processing Record 21 of Set 7 | port blair
# Processing Record 22 of Set 7 | bolshaya murta
# City not found. Skipping...
# Processing Record 23 of Set 7 | grenfell
# Processing Record 24 of Set 7 | mokobeng
# Processing Record 25 of Set 7 | kangaatsiaq
# Processing Record 26 of Set 7 | fairlie
# Processing Record 27 of Set 7 | batagay-alyta
# Processing Record 28 of Set 7 | barra do bugres
# Processing Record 29 of Set 7 | norrkoping
# Processing Record 30 of Set 7 | reinosa
# Processing Record 31 of Set 7 | porangatu
# Processing Record 32 of Set 7 | realeza
# Processing Record 33 of Set 7 | nizhniy odes
# Processing Record 34 of Set 7 | decatur
# Processing Record 35 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 7 | sahuaripa
# Processing Record 37 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 7 | najran
# Processing Record 39 of Set 7 | cubara
# Processing Record 40 of Set 7 | caconda
# Processing Record 41 of Set 7 | yumen
# Processing Record 42 of Set 7 | constitucion
# Processing Record 43 of Set 7 | necochea
# Processing Record 44 of Set 7 | kayfan
# City not found. Skipping...
# Processing Record 45 of Set 7 | maniitsoq
# Processing Record 46 of Set 7 | mayskiy
# Processing Record 47 of Set 7 | pokhara
# Processing Record 48 of Set 7 | caravelas
# Processing Record 49 of Set 7 | souillac
# Processing Record 50 of Set 7 | joshimath
# Processing Record 1 of Set 8 | tomatlan
# Processing Record 2 of Set 8 | northam
# Processing Record 3 of Set 8 | benguela
# Processing Record 4 of Set 8 | ahipara
# Processing Record 5 of Set 8 | vergara
# Processing Record 6 of Set 8 | cherskiy
# Processing Record 7 of Set 8 | morococha
# Processing Record 8 of Set 8 | luderitz
# Processing Record 9 of Set 8 | atherton
# Processing Record 10 of Set 8 | havoysund
# Processing Record 11 of Set 8 | zverinogolovskoye
# Processing Record 12 of Set 8 | dawei
# Processing Record 13 of Set 8 | grindavik
# Processing Record 14 of Set 8 | honningsvag
# Processing Record 15 of Set 8 | kargasok
# Processing Record 16 of Set 8 | padang
# Processing Record 17 of Set 8 | marawi
# Processing Record 18 of Set 8 | belyy yar
# Processing Record 19 of Set 8 | avera
# Processing Record 20 of Set 8 | ghanzi
# Processing Record 21 of Set 8 | sitka
# Processing Record 22 of Set 8 | borama
# City not found. Skipping...
# Processing Record 23 of Set 8 | fare
# Processing Record 24 of Set 8 | coahuayana
# Processing Record 25 of Set 8 | marsa matruh
# Processing Record 26 of Set 8 | ekpoma
# Processing Record 27 of Set 8 | ejido
# Processing Record 28 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 8 | vostochnyy
# Processing Record 30 of Set 8 | ostersund
# Processing Record 31 of Set 8 | road town
# Processing Record 32 of Set 8 | gatton
# Processing Record 33 of Set 8 | torbay
# Processing Record 34 of Set 8 | ancud
# Processing Record 35 of Set 8 | sinnamary
# Processing Record 36 of Set 8 | bose
# Processing Record 37 of Set 8 | maceio
# Processing Record 38 of Set 8 | chimbote
# Processing Record 39 of Set 8 | miyako
# Processing Record 40 of Set 8 | luganville
# Processing Record 41 of Set 8 | fortuna
# Processing Record 42 of Set 8 | yellowknife
# Processing Record 43 of Set 8 | bud
# Processing Record 44 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 8 | wad rawah
# Processing Record 46 of Set 8 | asfi
# Processing Record 47 of Set 8 | camacha
# Processing Record 48 of Set 8 | krasnoselkup
# Processing Record 49 of Set 8 | oriximina
# Processing Record 50 of Set 8 | kieta
# Processing Record 1 of Set 9 | ladybrand
# Processing Record 2 of Set 9 | mokrous
# Processing Record 3 of Set 9 | nouadhibou
# Processing Record 4 of Set 9 | beloha
# Processing Record 5 of Set 9 | merrill
# Processing Record 6 of Set 9 | slobozia
# Processing Record 7 of Set 9 | gorno-altaysk
# Processing Record 8 of Set 9 | manzhouli
# Processing Record 9 of Set 9 | qinhuangdao
# Processing Record 10 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 11 of Set 9 | severobaykalsk
# Processing Record 12 of Set 9 | brae
# Processing Record 13 of Set 9 | ayios matthaios
# City not found. Skipping...
# Processing Record 14 of Set 9 | sorland
# Processing Record 15 of Set 9 | tarakan
# Processing Record 16 of Set 9 | psebay
# Processing Record 17 of Set 9 | nicoya
# Processing Record 18 of Set 9 | kunming
# Processing Record 19 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 9 | bridlington
# Processing Record 21 of Set 9 | isangel
# Processing Record 22 of Set 9 | palana
# Processing Record 23 of Set 9 | chokurdakh
# Processing Record 24 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 9 | ola
# Processing Record 26 of Set 9 | karratha
# Processing Record 27 of Set 9 | shuya
# Processing Record 28 of Set 9 | bubaque
# Processing Record 29 of Set 9 | belawan
# Processing Record 30 of Set 9 | pangoa
# Processing Record 31 of Set 9 | dingalan
# Processing Record 32 of Set 9 | ciudad bolivar
# Processing Record 33 of Set 9 | kirkwall
# Processing Record 34 of Set 9 | samarai
# Processing Record 35 of Set 9 | soyo
# Processing Record 36 of Set 9 | batemans bay
# Processing Record 37 of Set 9 | antsohihy
# Processing Record 38 of Set 9 | otse
# Processing Record 39 of Set 9 | stettler
# Processing Record 40 of Set 9 | parrita
# Processing Record 41 of Set 9 | rosarito
# Processing Record 42 of Set 9 | lasa
# Processing Record 43 of Set 9 | kilindoni
# Processing Record 44 of Set 9 | leshukonskoye
# Processing Record 45 of Set 9 | lucapa
# Processing Record 46 of Set 9 | erzin
# Processing Record 47 of Set 9 | royan
# Processing Record 48 of Set 9 | chipata
# Processing Record 49 of Set 9 | clovis
# Processing Record 50 of Set 9 | ler
# Processing Record 1 of Set 10 | bambanglipuro
# Processing Record 2 of Set 10 | kikwit
# Processing Record 3 of Set 10 | ciudad guayana
# Processing Record 4 of Set 10 | kawalu
# Processing Record 5 of Set 10 | olafsvik
# Processing Record 6 of Set 10 | athabasca
# Processing Record 7 of Set 10 | faridabad
# Processing Record 8 of Set 10 | rouvroy
# Processing Record 9 of Set 10 | saldanha
# Processing Record 10 of Set 10 | balkhash
# Processing Record 11 of Set 10 | sioux lookout
# Processing Record 12 of Set 10 | castlemaine
# Processing Record 13 of Set 10 | kibaya
# Processing Record 14 of Set 10 | karasburg
# Processing Record 15 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 16 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 10 | pavlodolskaya
# Processing Record 18 of Set 10 | houma
# Processing Record 19 of Set 10 | diu
# Processing Record 20 of Set 10 | monteria
# Processing Record 21 of Set 10 | kitimat
# Processing Record 22 of Set 10 | kaili
# Processing Record 23 of Set 10 | mahibadhoo
# Processing Record 24 of Set 10 | amapa
# Processing Record 25 of Set 10 | bantou
# Processing Record 26 of Set 10 | manjo
# Processing Record 27 of Set 10 | hervey bay
# Processing Record 28 of Set 10 | kendari
# Processing Record 29 of Set 10 | xinzhi
# Processing Record 30 of Set 10 | merauke
# Processing Record 31 of Set 10 | burayevo
# Processing Record 32 of Set 10 | suzun
# Processing Record 33 of Set 10 | rudnyy
# Processing Record 34 of Set 10 | san rafael del sur
# Processing Record 35 of Set 10 | aasiaat
# Processing Record 36 of Set 10 | hede
# Processing Record 37 of Set 10 | chowchilla
# Processing Record 38 of Set 10 | port-gentil
# Processing Record 39 of Set 10 | paripiranga
# Processing Record 40 of Set 10 | izberbash
# Processing Record 41 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 10 | saint-pierre
# Processing Record 43 of Set 10 | konstantinovo
# Processing Record 44 of Set 10 | sao filipe
# Processing Record 45 of Set 10 | hit
# Processing Record 46 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 47 of Set 10 | urumqi
# Processing Record 48 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 10 | dicabisagan
# Processing Record 50 of Set 10 | vanimo
# Processing Record 1 of Set 11 | hasaki
# Processing Record 2 of Set 11 | bahia blanca
# Processing Record 3 of Set 11 | gwadar
# Processing Record 4 of Set 11 | port augusta
# Processing Record 5 of Set 11 | tateyama
# Processing Record 6 of Set 11 | payo
# Processing Record 7 of Set 11 | cranbrook
# Processing Record 8 of Set 11 | mattawa
# Processing Record 9 of Set 11 | dustlik
# Processing Record 10 of Set 11 | poronaysk
# Processing Record 11 of Set 11 | bonavista
# Processing Record 12 of Set 11 | khorol
# Processing Record 13 of Set 11 | mama
# Processing Record 14 of Set 11 | ambilobe
# Processing Record 15 of Set 11 | les cayes
# Processing Record 16 of Set 11 | jovellar
# Processing Record 17 of Set 11 | lockport
# Processing Record 18 of Set 11 | mari-turek
# Processing Record 19 of Set 11 | stadthagen
# Processing Record 20 of Set 11 | yulara
# Processing Record 21 of Set 11 | broome
# Processing Record 22 of Set 11 | trairi
# Processing Record 23 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 24 of Set 11 | suntar
# Processing Record 25 of Set 11 | sinjai
# Processing Record 26 of Set 11 | longyearbyen
# Processing Record 27 of Set 11 | vestmannaeyjar
# Processing Record 28 of Set 11 | kyabe
# Processing Record 29 of Set 11 | half moon bay
# Processing Record 30 of Set 11 | talaya
# Processing Record 31 of Set 11 | juba
# Processing Record 32 of Set 11 | paamiut
# Processing Record 33 of Set 11 | lucatan
# City not found. Skipping...
# Processing Record 34 of Set 11 | gilbues
# Processing Record 35 of Set 11 | ixtapa
# Processing Record 36 of Set 11 | lavrentiya
# Processing Record 37 of Set 11 | valparaiso
# Processing Record 38 of Set 11 | coquimbo
# Processing Record 39 of Set 11 | kuytun
# Processing Record 40 of Set 11 | olinda
# Processing Record 41 of Set 11 | aktas
# Processing Record 42 of Set 11 | nokaneng
# Processing Record 43 of Set 11 | makasar
# Processing Record 44 of Set 11 | domoni
# Processing Record 45 of Set 11 | vostok
# Processing Record 46 of Set 11 | peace river
# Processing Record 47 of Set 11 | wasilla
# Processing Record 48 of Set 11 | hamilton
# Processing Record 49 of Set 11 | ust-kuyga
# Processing Record 50 of Set 11 | linguere
# Processing Record 1 of Set 12 | nuuk
# Processing Record 2 of Set 12 | raudeberg
# Processing Record 3 of Set 12 | nuevo casas grandes
# Processing Record 4 of Set 12 | novyy nekouz
# Processing Record 5 of Set 12 | labuhan
# Processing Record 6 of Set 12 | tulagi
# Processing Record 7 of Set 12 | rotifunk
# Processing Record 8 of Set 12 | mogadishu
# Processing Record 9 of Set 12 | salme
# Processing Record 10 of Set 12 | maldonado
# Processing Record 11 of Set 12 | uige
# Processing Record 12 of Set 12 | teluknaga
# Processing Record 13 of Set 12 | laguna
# Processing Record 14 of Set 12 | nanortalik
# Processing Record 15 of Set 12 | akureyri
# Processing Record 16 of Set 12 | cayenne
# Processing Record 17 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 12 | gornopravdinsk
# Processing Record 19 of Set 12 | dhandhuka
# Processing Record 20 of Set 12 | satipo
# Processing Record 21 of Set 12 | mercedes
# Processing Record 22 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 12 | wanning
# Processing Record 24 of Set 12 | araceli
# Processing Record 25 of Set 12 | windhoek
# Processing Record 26 of Set 12 | jiuquan
# Processing Record 27 of Set 12 | bayji
# Processing Record 28 of Set 12 | shihezi
# Processing Record 29 of Set 12 | kokkola
# Processing Record 30 of Set 12 | langsa
# Processing Record 31 of Set 12 | elko
# Processing Record 32 of Set 12 | vidim
# Processing Record 33 of Set 12 | malakal
# Processing Record 34 of Set 12 | rio gallegos
# Processing Record 35 of Set 12 | pontianak
# Processing Record 36 of Set 12 | ascension
# Processing Record 37 of Set 12 | pauini
# Processing Record 38 of Set 12 | solnechnyy
# Processing Record 39 of Set 12 | parati
# Processing Record 40 of Set 12 | kipushi
# Processing Record 41 of Set 12 | cuauhtemoc
# Processing Record 42 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 43 of Set 12 | sakakah
# Processing Record 44 of Set 12 | bury saint edmunds
# City not found. Skipping...
# Processing Record 45 of Set 12 | okha
# Processing Record 46 of Set 12 | ewa beach
# Processing Record 47 of Set 12 | garwolin
# Processing Record 48 of Set 12 | doka
# Processing Record 49 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 50 of Set 12 | touros
# Processing Record 1 of Set 13 | kodinar
# Processing Record 2 of Set 13 | baft
# Processing Record 3 of Set 13 | sabang
# Processing Record 4 of Set 13 | karlskoga
# Processing Record 5 of Set 13 | luwuk
# Processing Record 6 of Set 13 | ahuimanu
# Processing Record 7 of Set 13 | north bend
# Processing Record 8 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 13 | annau
# Processing Record 10 of Set 13 | arlit
# Processing Record 11 of Set 13 | bad munstereifel
# Processing Record 12 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 13 | alikovo
# Processing Record 14 of Set 13 | ust-ilimsk
# Processing Record 15 of Set 13 | esmeraldas
# Processing Record 16 of Set 13 | mindelo
# Processing Record 17 of Set 13 | mecca
# Processing Record 18 of Set 13 | katangli
# Processing Record 19 of Set 13 | waipawa
# Processing Record 20 of Set 13 | pafos
# Processing Record 21 of Set 13 | powell
# Processing Record 22 of Set 13 | broken hill
# Processing Record 23 of Set 13 | san carlos de bariloche
# Processing Record 24 of Set 13 | cabedelo
# Processing Record 25 of Set 13 | kysyl-syr
# Processing Record 26 of Set 13 | kondinskoye
# Processing Record 27 of Set 13 | sitia
# Processing Record 28 of Set 13 | pinos
# Processing Record 29 of Set 13 | samokov
# Processing Record 30 of Set 13 | amazar
# Processing Record 31 of Set 13 | vershino-shakhtaminskiy
# Processing Record 32 of Set 13 | takoradi
# Processing Record 33 of Set 13 | butembo
# Processing Record 34 of Set 13 | natal
# Processing Record 35 of Set 13 | coihaique
# Processing Record 36 of Set 13 | waitati
# Processing Record 37 of Set 13 | buraydah
# Processing Record 38 of Set 13 | mehamn
# Processing Record 39 of Set 13 | ampanihy
# Processing Record 40 of Set 13 | san jose
# Processing Record 41 of Set 13 | kozhva
# Processing Record 42 of Set 13 | inirida
# Processing Record 43 of Set 13 | pervoye maya
# Processing Record 44 of Set 13 | sovetskiy
# Processing Record 45 of Set 13 | shizunai
# Processing Record 46 of Set 13 | tanout
# Processing Record 47 of Set 13 | westport
# Processing Record 48 of Set 13 | santa isabel do rio negro
# Processing Record 49 of Set 13 | tuatapere
# Processing Record 50 of Set 13 | vyara
# Processing Record 1 of Set 14 | iracoubo
# Processing Record 2 of Set 14 | watertown
# Processing Record 3 of Set 14 | sibu
# Processing Record 4 of Set 14 | daxian
# City not found. Skipping...
# Processing Record 5 of Set 14 | imbituba
# Processing Record 6 of Set 14 | ban chang
# Processing Record 7 of Set 14 | wajima
# Processing Record 8 of Set 14 | beni
# Processing Record 9 of Set 14 | fuyu
# Processing Record 10 of Set 14 | fuerte olimpo
# Processing Record 11 of Set 14 | sisimiut
# Processing Record 12 of Set 14 | acapulco
# Processing Record 13 of Set 14 | troitskoye
# Processing Record 14 of Set 14 | the pas
# Processing Record 15 of Set 14 | bundaberg
# Processing Record 16 of Set 14 | omsukchan
# Processing Record 17 of Set 14 | bilma
# Processing Record 18 of Set 14 | miri
# Processing Record 19 of Set 14 | tezu
# Processing Record 20 of Set 14 | mananjary
# Processing Record 21 of Set 14 | macau
# Processing Record 22 of Set 14 | shu
# Processing Record 23 of Set 14 | camapua
# Processing Record 24 of Set 14 | mokrousovo
# Processing Record 25 of Set 14 | brigham city
# Processing Record 26 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 14 | luvianos
# Processing Record 28 of Set 14 | zanjan
# Processing Record 29 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 14 | washington
# Processing Record 31 of Set 14 | sao joao da barra
# Processing Record 32 of Set 14 | sechura
# Processing Record 33 of Set 14 | chadan
# Processing Record 34 of Set 14 | dire dawa
# Processing Record 35 of Set 14 | lumut
# Processing Record 36 of Set 14 | fairbanks
# Processing Record 37 of Set 14 | natitingou
# Processing Record 38 of Set 14 | humberto de campos
# Processing Record 39 of Set 14 | paris
# Processing Record 40 of Set 14 | provins
# Processing Record 41 of Set 14 | san rafael
# Processing Record 42 of Set 14 | banda aceh
# Processing Record 43 of Set 14 | point pedro
# Processing Record 44 of Set 14 | oktyabrskoye
# Processing Record 45 of Set 14 | maragogi
# Processing Record 46 of Set 14 | ningyang
# Processing Record 47 of Set 14 | zaysan
# Processing Record 48 of Set 14 | vanavara
# Processing Record 49 of Set 14 | guanica
# Processing Record 50 of Set 14 | san vicente
# Processing Record 1 of Set 15 | fredericksburg
# Processing Record 2 of Set 15 | schio
# Processing Record 3 of Set 15 | nemuro
# Processing Record 4 of Set 15 | bilibino
# Processing Record 5 of Set 15 | zemio
# Processing Record 6 of Set 15 | mendi
# Processing Record 7 of Set 15 | kavaratti
# Processing Record 8 of Set 15 | aljezur
# Processing Record 9 of Set 15 | markova
# Processing Record 10 of Set 15 | fairview
# Processing Record 11 of Set 15 | klaksvik
# Processing Record 12 of Set 15 | zyryanka
# Processing Record 13 of Set 15 | akdepe
# Processing Record 14 of Set 15 | adrar
# Processing Record 15 of Set 15 | hobyo
# Processing Record 16 of Set 15 | stornoway
# Processing Record 17 of Set 15 | leningradskiy
# Processing Record 18 of Set 15 | la ligua
# Processing Record 19 of Set 15 | cap malheureux
# Processing Record 20 of Set 15 | itaituba
# Processing Record 21 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 22 of Set 15 | ossora
# Processing Record 23 of Set 15 | ulu-telyak
# Processing Record 24 of Set 15 | svetlogorsk
# Processing Record 25 of Set 15 | sainte-suzanne
# Processing Record 26 of Set 15 | buta
# Processing Record 27 of Set 15 | saraza
# Processing Record 28 of Set 15 | lyngseidet
# Processing Record 29 of Set 15 | port moresby
# Processing Record 30 of Set 15 | gualaquiza
# Processing Record 31 of Set 15 | caluquembe
# Processing Record 32 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 15 | taksimo
# Processing Record 34 of Set 15 | prenzlau
# Processing Record 35 of Set 15 | qaqortoq
# Processing Record 36 of Set 15 | parana
# Processing Record 37 of Set 15 | aflao
# Processing Record 38 of Set 15 | goderich
# Processing Record 39 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 40 of Set 15 | sayyan
# Processing Record 41 of Set 15 | tazovskiy
# Processing Record 42 of Set 15 | north platte
# Processing Record 43 of Set 15 | marv dasht
# City not found. Skipping...
# Processing Record 44 of Set 15 | qurbus
# Processing Record 45 of Set 15 | cornwall
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
json.dumps(city_weather)
# Out:
# '{"coord": {"lon": -74.7281, "lat": 45.0181}, "weather": [{"id": 800, "main": "Clear", "description": "clear sky", "icon": "01d"}], "base": "stations", "main": {"temp": 68.13, "feels_like": 67.64, "temp_min": 67.24, "temp_max": 68.38, "pressure": 1008, "humidity": 64}, "visibility": 10000, "wind": {"speed": 11.5, "deg": 250, "gust": 18.41}, "clouds": {"all": 0}, "dt": 1654896328, "sys": {"type": 1, "id": 4986, "country": "CA", "sunrise": 1654852329, "sunset": 1654908289}, "timezone": -14400, "id": 5928065, "name": "Cornwall", "cod": 200}'

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Pacifica      US  37.6138 -122.4869     99.23        64          20
# 1         Opuwo      NA -18.0607   13.8400     60.15        40           0
# 2        Castro      BR -24.7911  -50.0119     55.94        93         100
# 3          Ayan      RU  56.4500  138.1667     43.12        91          97
# 4  San Patricio      US  28.0170  -97.5169    101.12        44           5
# 5   San Quintin      MX  30.4833 -115.9500     73.15        60           1
# 6       Husavik      IS  66.0449  -17.3389     42.57        95         100
# 7          Sola      VU -13.8833  167.5500     81.27        89          20
# 8          Nome      US  64.5011 -165.4064     59.07        29           0
# 9        Albany      US  42.6001  -73.9662     75.16        48          10
#
#    Wind Speed Current Description
# 0       25.32          few clouds
# 1        7.72           clear sky
# 2        4.23     overcast clouds
# 3        0.89     overcast clouds
# 4       21.00           clear sky
# 5        8.55           clear sky
# 6        9.01     overcast clouds
# 7        0.00          few clouds
# 8       17.27           clear sky
# 9        1.01           clear sky

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
